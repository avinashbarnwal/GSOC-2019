# %%
import xgboost
import pandas            as pd
import numpy             as np
import matplotlib.pyplot as plt

# %%
def getInputOutputFolder(fileFlag=None):
    f  = open("data_file.txt", "r")
    i  = 0
    for l in f.readlines():
        if fileFlag<32:
            if i==fileFlag:
                foldName = l[:-1]
        if fileFlag==32:
            if i==fileFlag:
                foldName = l
        
        i = i+1
    f.close()
    dataNameSplit = foldName.split("/")
    inputFileName  = '../../data/'+ dataNameSplit[1]+'/inputs.csv'
    outputFileName = '../../data/'+ dataNameSplit[1]+'/outputs.csv'
    foldName       = '../../'+foldName
    return inputFileName,outputFileName,foldName,dataNameSplit[1]

# %%
# Input the File Number
# Not Working - 17,18,19,20,21,22,23,24,25
fileFlag = 25
inputFileName,outputFileName,foldName,dataName = getInputOutputFolder(fileFlag)
print(inputFileName)
print(outputFileName)
print(foldName)
print(dataName)
# Out:
# ../../data/systematic/inputs.csv
# ../../data/systematic/outputs.csv
# ../../data/systematic/cv/R-3.6.0-chrom/folds.csv
# systematic

# %%
input     = pd.read_csv(inputFileName)
label     = pd.read_csv(outputFileName)
folds     = pd.read_csv(foldName)
folds_iter = folds['fold'].unique()
print(folds_iter)
input.replace([np.inf, -np.inf], np.nan,inplace=True)
# Out:
# [1 2 3 4 5 6]

# %%
colnames       = input.columns.values
colnamesSeries = input.isna().sum()
nullColnames   = list(colnamesSeries.index[colnamesSeries>0].values)
nullColnames.append('sequenceID')
colnames       = [x for x in colnames if x not in nullColnames]

# %%
def chart_creation_xgboost(res,chart_title,chart_name):
    
    min_valid = round(np.min(res['test']['normal,1.0']),4)
    min_train = round(np.min(res['train']['normal,1.0']),4)
    min_iter  = round(np.nanargmin(res['test']['normal,1.0']),0)

    textstr = '\n'.join((
                    'Min Train = %.2f' % (min_train, ),
                    'Min Valid = %.2f' % (min_valid, ),
                    'Min Iter  = %.2f' % (min_iter, )))

    props = dict(boxstyle='round', facecolor='wheat', alpha=0.5,edgecolor="black")
    
    fig,ax1       = plt.subplots()
    ax2           = ax1.twinx()

    ln1 = ax1.plot(res['train']['normal,1.0'],color='blue',label='Training')
    ln2 = ax2.plot(res['test']['normal,1.0'],color='orange',label='Validation')
    
    lns = ln1 + ln2
    
    labs = [l.get_label() for l in lns]
    ax1.legend(lns, labs, loc='lower left',fancybox='round', facecolor='wheat',fontsize=8)
    
    ax1.set_xlabel("Number of Iterations(Trees)")
    ax1.set_ylabel("Training Negative Likelihood(Loss)")
    ax2.set_ylabel("Validation Negative Likelihood(Loss)")
    ax2.text(0.7, 0.90, textstr, transform=ax1.transAxes, fontsize=8,
        verticalalignment='top', bbox=props)
    plt.title(chart_title)
    plt.show()
    fig.savefig(chart_name)
    
def generate_result(X,y_lower,y_higher,params,X_val=None,y_lower_val=None,y_higher_val=None):
    
    res    = {}
    dtrain = xgboost.DMatrix(X)
    dtrain.set_float_info("label_lower_bound",y_lower)
    dtrain.set_float_info("label_upper_bound",y_higher)
    
    dtest  = xgboost.DMatrix(X_val)
    dtest.set_float_info("label_lower_bound",y_lower_val)
    dtest.set_float_info("label_upper_bound",y_higher_val)
    
    bst    = xgboost.train(params,dtrain,num_boost_round=50,evals=[(dtrain,"train"),(dtest,"test")],evals_result=res)
    return res

# %%
for i in folds_iter:
    
    test_fold    = i
    test_id      = folds[folds["fold"]==i]['sequenceID']
    train_id     = folds[folds["fold"]!=i]['sequenceID']
    nullId       = label[(label['min.log.lambda']==-float('inf'))&(label['max.log.lambda']==float('inf'))]['sequenceID']
    X            = input[input['sequenceID'].isin(train_id)&(~input['sequenceID'].isin(nullId))]
    X_val        = input[input['sequenceID'].isin(test_id)&(~input['sequenceID'].isin(nullId))]
    
    X            = X[colnames]
    X_val        = X_val[colnames]
    y_label      = label[label['sequenceID'].isin(train_id)&(~label['sequenceID'].isin(nullId))]
    y_label_test = label[label['sequenceID'].isin(test_id)&(~label['sequenceID'].isin(nullId))]
    
    y_lower      = np.array(list(map(lambda x: x if x == float('inf') or x == -float('inf') else np.exp(x),y_label['min.log.lambda'])))
    y_higher     = np.array(list(map(lambda x: x if x == float('inf') or x == -float('inf') else np.exp(x),y_label['max.log.lambda'])))
    y_lower_val  = np.array(list(map(lambda x: x if x == float('inf') or x == -float('inf') else np.exp(x),y_label_test['min.log.lambda'])))
    y_higher_val = np.array(list(map(lambda x: x if x == float('inf') or x == -float('inf') else np.exp(x),y_label_test['max.log.lambda'])))
    
    data_name    = dataName
    title        = 'Loss=LogLoss,Data='+data_name+' Test Fold='+str(test_fold)
    file_name    = title+'.png'
    
    params = {'learning_rate':0.1, 'aft_noise_distribution' : 'normal', 'aft_sigma': 1.0,'eval_metric':'aft-nloglik@normal,1.0','objective':"aft:survival"}
    bst    = generate_result(X,y_lower,y_higher,params,X_val,y_lower_val,y_higher_val)
    chart_creation_xgboost(bst,title,file_name)
# Out:
# [0]	train-normal,1.0:826.249	test-normal,1.0:425.893
# [1]	train-normal,1.0:722.96	test-normal,1.0:391.097
# [2]	train-normal,1.0:635.407	test-normal,1.0:362.975
# [3]	train-normal,1.0:560.443	test-normal,1.0:340.87
# [4]	train-normal,1.0:497.202	test-normal,1.0:318.308
# [5]	train-normal,1.0:442.402	test-normal,1.0:294.967
# [6]	train-normal,1.0:394.63	test-normal,1.0:274.088
# [7]	train-normal,1.0:353.059	test-normal,1.0:256.873
# [8]	train-normal,1.0:317.513	test-normal,1.0:240.382
# [9]	train-normal,1.0:286.861	test-normal,1.0:228.196
# [10]	train-normal,1.0:260.177	test-normal,1.0:217.931
# [11]	train-normal,1.0:237.632	test-normal,1.0:206.122
# [12]	train-normal,1.0:216.937	test-normal,1.0:195.519
# [13]	train-normal,1.0:198.261	test-normal,1.0:186.339
# [14]	train-normal,1.0:181.531	test-normal,1.0:180.597
# [15]	train-normal,1.0:167.742	test-normal,1.0:174.907
# [16]	train-normal,1.0:154.737	test-normal,1.0:168.394
# [17]	train-normal,1.0:143.663	test-normal,1.0:161.978
# [18]	train-normal,1.0:133.117	test-normal,1.0:158.886
# [19]	train-normal,1.0:123.647	test-normal,1.0:151.203
# [20]	train-normal,1.0:115.406	test-normal,1.0:146.922
# [21]	train-normal,1.0:107.749	test-normal,1.0:142.353
# [22]	train-normal,1.0:101.516	test-normal,1.0:138.63
# [23]	train-normal,1.0:95.3544	test-normal,1.0:137.077
# [24]	train-normal,1.0:90.1361	test-normal,1.0:134.405
# [25]	train-normal,1.0:85.3752	test-normal,1.0:130.489
# [26]	train-normal,1.0:80.5795	test-normal,1.0:126.722
# [27]	train-normal,1.0:76.4199	test-normal,1.0:126.428
# [28]	train-normal,1.0:73.0804	test-normal,1.0:124.498
# [29]	train-normal,1.0:68.8444	test-normal,1.0:122.791
# [30]	train-normal,1.0:65.6574	test-normal,1.0:121.009
# [31]	train-normal,1.0:62.5406	test-normal,1.0:117.518
# [32]	train-normal,1.0:59.7693	test-normal,1.0:114.735
# [33]	train-normal,1.0:57.5319	test-normal,1.0:112.841
# [34]	train-normal,1.0:55.3744	test-normal,1.0:110.314
# [35]	train-normal,1.0:53.4272	test-normal,1.0:108.466
# [36]	train-normal,1.0:50.7428	test-normal,1.0:109.218
# [37]	train-normal,1.0:47.8903	test-normal,1.0:108.358
# [38]	train-normal,1.0:45.3065	test-normal,1.0:107.935
# [39]	train-normal,1.0:43.1472	test-normal,1.0:106.778
# [40]	train-normal,1.0:41.1493	test-normal,1.0:105.639
# [41]	train-normal,1.0:39.216	test-normal,1.0:107.45
# [42]	train-normal,1.0:38.0258	test-normal,1.0:106.628
# [43]	train-normal,1.0:36.2955	test-normal,1.0:106.279
# [44]	train-normal,1.0:34.7035	test-normal,1.0:106.978
# [45]	train-normal,1.0:33.2888	test-normal,1.0:106.053
# [46]	train-normal,1.0:32.5874	test-normal,1.0:104.926
# [47]	train-normal,1.0:31.2636	test-normal,1.0:104.592
# [48]	train-normal,1.0:30.333	test-normal,1.0:104.659
# [49]	train-normal,1.0:29.6704	test-normal,1.0:104.473
# [0]	train-normal,1.0:1081.12	test-normal,1.0:150.652
# [1]	train-normal,1.0:944.268	test-normal,1.0:133.908
# [2]	train-normal,1.0:828.009	test-normal,1.0:119.221
# [3]	train-normal,1.0:729.548	test-normal,1.0:106.643
# [4]	train-normal,1.0:643.795	test-normal,1.0:96.1251
# [5]	train-normal,1.0:571.325	test-normal,1.0:87.0243
# [6]	train-normal,1.0:509.374	test-normal,1.0:79.5277
# [7]	train-normal,1.0:455.315	test-normal,1.0:72.8036
# [8]	train-normal,1.0:407.934	test-normal,1.0:67.107
# [9]	train-normal,1.0:368.036	test-normal,1.0:62.0339
# [10]	train-normal,1.0:332.33	test-normal,1.0:58.2429
# [11]	train-normal,1.0:300.984	test-normal,1.0:54.7675
# [12]	train-normal,1.0:272.99	test-normal,1.0:51.3422
# [13]	train-normal,1.0:248.251	test-normal,1.0:49.007
# [14]	train-normal,1.0:227.003	test-normal,1.0:46.4512
# [15]	train-normal,1.0:207.885	test-normal,1.0:44.1828
# [16]	train-normal,1.0:191.473	test-normal,1.0:42.326
# [17]	train-normal,1.0:176.388	test-normal,1.0:40.3186
# [18]	train-normal,1.0:162.637	test-normal,1.0:39.3104
# [19]	train-normal,1.0:150.57	test-normal,1.0:38.4209
# [20]	train-normal,1.0:139.749	test-normal,1.0:37.654
# [21]	train-normal,1.0:130.233	test-normal,1.0:36.7536
# [22]	train-normal,1.0:121.889	test-normal,1.0:36.1645
# [23]	train-normal,1.0:114.216	test-normal,1.0:35.5223
# [24]	train-normal,1.0:106.716	test-normal,1.0:34.982
# [25]	train-normal,1.0:100.261	test-normal,1.0:34.6841
# [26]	train-normal,1.0:95.1076	test-normal,1.0:34.0212
# [27]	train-normal,1.0:89.3843	test-normal,1.0:33.8706
# [28]	train-normal,1.0:84.4488	test-normal,1.0:33.4151
# [29]	train-normal,1.0:80.2607	test-normal,1.0:33.1189
# [30]	train-normal,1.0:76.4015	test-normal,1.0:32.9218
# [31]	train-normal,1.0:72.7211	test-normal,1.0:32.8129
# [32]	train-normal,1.0:69.5852	test-normal,1.0:32.3541
# [33]	train-normal,1.0:66.4513	test-normal,1.0:32.6709
# [34]	train-normal,1.0:63.5144	test-normal,1.0:32.3814
# [35]	train-normal,1.0:60.3392	test-normal,1.0:32.3607
# [36]	train-normal,1.0:58.3047	test-normal,1.0:32.3348
# [37]	train-normal,1.0:55.6228	test-normal,1.0:32.0299
# [38]	train-normal,1.0:53.306	test-normal,1.0:32.1716
# [39]	train-normal,1.0:51.1832	test-normal,1.0:32.2159
# [40]	train-normal,1.0:49.2192	test-normal,1.0:31.8678
# [41]	train-normal,1.0:47.2864	test-normal,1.0:31.7022
# [42]	train-normal,1.0:45.1981	test-normal,1.0:31.5436
# [43]	train-normal,1.0:43.8576	test-normal,1.0:31.8139
# [44]	train-normal,1.0:42.4985	test-normal,1.0:31.5261
# [45]	train-normal,1.0:40.899	test-normal,1.0:31.2581
# [46]	train-normal,1.0:39.4235	test-normal,1.0:31.2585
# [47]	train-normal,1.0:38.1842	test-normal,1.0:31.473
# [48]	train-normal,1.0:37.0171	test-normal,1.0:31.6148
# [49]	train-normal,1.0:36.0083	test-normal,1.0:31.6927
# [0]	train-normal,1.0:1048.01	test-normal,1.0:187.325
# [1]	train-normal,1.0:912.513	test-normal,1.0:166.251
# [2]	train-normal,1.0:797.522	test-normal,1.0:150.097
# [3]	train-normal,1.0:699.733	test-normal,1.0:137.058
# [4]	train-normal,1.0:616.439	test-normal,1.0:124.884
# [5]	train-normal,1.0:545.398	test-normal,1.0:114.541
# [6]	train-normal,1.0:483.5	test-normal,1.0:105.854
# [7]	train-normal,1.0:430.769	test-normal,1.0:99.1979
# [8]	train-normal,1.0:384.495	test-normal,1.0:93.8323
# [9]	train-normal,1.0:344.919	test-normal,1.0:88.5825
# [10]	train-normal,1.0:310.722	test-normal,1.0:83.7184
# [11]	train-normal,1.0:281.046	test-normal,1.0:80.7107
# [12]	train-normal,1.0:254.855	test-normal,1.0:77.3499
# [13]	train-normal,1.0:231.833	test-normal,1.0:74.7852
# [14]	train-normal,1.0:211.89	test-normal,1.0:72.5187
# [15]	train-normal,1.0:192.045	test-normal,1.0:70.4675
# [16]	train-normal,1.0:175.334	test-normal,1.0:68.982
# [17]	train-normal,1.0:161.524	test-normal,1.0:68.8818
# [18]	train-normal,1.0:148.913	test-normal,1.0:68.4243
# [19]	train-normal,1.0:138.123	test-normal,1.0:67.4455
# [20]	train-normal,1.0:127.733	test-normal,1.0:66.7319
# [21]	train-normal,1.0:118.81	test-normal,1.0:66.5054
# [22]	train-normal,1.0:111.679	test-normal,1.0:66.3265
# [23]	train-normal,1.0:103.324	test-normal,1.0:66.609
# [24]	train-normal,1.0:96.1758	test-normal,1.0:66.7317
# [25]	train-normal,1.0:89.4506	test-normal,1.0:66.6172
# [26]	train-normal,1.0:83.5956	test-normal,1.0:67.3481
# [27]	train-normal,1.0:78.586	test-normal,1.0:68.1328
# [28]	train-normal,1.0:74.067	test-normal,1.0:69.0179
# [29]	train-normal,1.0:69.9733	test-normal,1.0:69.5052
# [30]	train-normal,1.0:66.5259	test-normal,1.0:69.9373
# [31]	train-normal,1.0:62.403	test-normal,1.0:69.9279
# [32]	train-normal,1.0:59.2722	test-normal,1.0:70.5697
# [33]	train-normal,1.0:56.3281	test-normal,1.0:71.1329
# [34]	train-normal,1.0:53.7322	test-normal,1.0:71.9459
# [35]	train-normal,1.0:50.9141	test-normal,1.0:72.3109
# [36]	train-normal,1.0:48.1787	test-normal,1.0:72.5686
# [37]	train-normal,1.0:45.9646	test-normal,1.0:72.9231
# [38]	train-normal,1.0:43.5341	test-normal,1.0:73.7128
# [39]	train-normal,1.0:41.8816	test-normal,1.0:74.2471
# [40]	train-normal,1.0:40.1131	test-normal,1.0:75.1318
# [41]	train-normal,1.0:38.0929	test-normal,1.0:75.0657
# [42]	train-normal,1.0:36.3896	test-normal,1.0:75.9238
# [43]	train-normal,1.0:34.8863	test-normal,1.0:76.4319
# [44]	train-normal,1.0:33.6966	test-normal,1.0:76.841
# [45]	train-normal,1.0:32.6742	test-normal,1.0:77.8033
# [46]	train-normal,1.0:31.6048	test-normal,1.0:78.6025
# [47]	train-normal,1.0:30.4258	test-normal,1.0:79.3459
# [48]	train-normal,1.0:29.2154	test-normal,1.0:80.1521
# [49]	train-normal,1.0:27.8417	test-normal,1.0:80.9501
# [0]	train-normal,1.0:1077.09	test-normal,1.0:150.883
# [1]	train-normal,1.0:939.704	test-normal,1.0:129.893
# [2]	train-normal,1.0:823.567	test-normal,1.0:112.3
# [3]	train-normal,1.0:724.817	test-normal,1.0:98.4755
# [4]	train-normal,1.0:640.574	test-normal,1.0:87.031
# [5]	train-normal,1.0:568.141	test-normal,1.0:77.0965
# [6]	train-normal,1.0:505.937	test-normal,1.0:68.8858
# [7]	train-normal,1.0:450.942	test-normal,1.0:62.0322
# [8]	train-normal,1.0:404.043	test-normal,1.0:56.0395
# [9]	train-normal,1.0:363.113	test-normal,1.0:51.3712
# [10]	train-normal,1.0:327.061	test-normal,1.0:47.3026
# [11]	train-normal,1.0:295.223	test-normal,1.0:44.0505
# [12]	train-normal,1.0:268.075	test-normal,1.0:41.5357
# [13]	train-normal,1.0:244.493	test-normal,1.0:39.5731
# [14]	train-normal,1.0:223.1	test-normal,1.0:37.5808
# [15]	train-normal,1.0:204.389	test-normal,1.0:35.8971
# [16]	train-normal,1.0:188.235	test-normal,1.0:34.6311
# [17]	train-normal,1.0:174.027	test-normal,1.0:33.5579
# [18]	train-normal,1.0:161.047	test-normal,1.0:32.8976
# [19]	train-normal,1.0:148.83	test-normal,1.0:32.228
# [20]	train-normal,1.0:137.968	test-normal,1.0:31.7558
# [21]	train-normal,1.0:128.471	test-normal,1.0:31.2462
# [22]	train-normal,1.0:119.605	test-normal,1.0:30.7319
# [23]	train-normal,1.0:111.874	test-normal,1.0:30.7209
# [24]	train-normal,1.0:104.715	test-normal,1.0:30.8696
# [25]	train-normal,1.0:98.5115	test-normal,1.0:30.9476
# [26]	train-normal,1.0:92.9846	test-normal,1.0:31.2455
# [27]	train-normal,1.0:87.1513	test-normal,1.0:31.2763
# [28]	train-normal,1.0:82.3048	test-normal,1.0:31.0975
# [29]	train-normal,1.0:77.4168	test-normal,1.0:31.3074
# [30]	train-normal,1.0:73.4003	test-normal,1.0:31.2838
# [31]	train-normal,1.0:69.371	test-normal,1.0:31.6687
# [32]	train-normal,1.0:66.4708	test-normal,1.0:32.2243
# [33]	train-normal,1.0:63.5116	test-normal,1.0:32.3821
# [34]	train-normal,1.0:60.8508	test-normal,1.0:32.6679
# [35]	train-normal,1.0:58.0528	test-normal,1.0:32.4514
# [36]	train-normal,1.0:55.8118	test-normal,1.0:32.5082
# [37]	train-normal,1.0:53.1785	test-normal,1.0:32.858
# [38]	train-normal,1.0:50.8991	test-normal,1.0:33.4961
# [39]	train-normal,1.0:48.7396	test-normal,1.0:33.8967
# [40]	train-normal,1.0:47.213	test-normal,1.0:34.3933
# [41]	train-normal,1.0:45.3185	test-normal,1.0:34.95
# [42]	train-normal,1.0:43.9175	test-normal,1.0:35.2742
# [43]	train-normal,1.0:42.6199	test-normal,1.0:35.5087
# [44]	train-normal,1.0:41.0597	test-normal,1.0:35.8291
# [45]	train-normal,1.0:39.7489	test-normal,1.0:35.7807
# [46]	train-normal,1.0:38.5146	test-normal,1.0:35.9965
# [47]	train-normal,1.0:37.3996	test-normal,1.0:36.164
# [48]	train-normal,1.0:36.3605	test-normal,1.0:36.58
# [49]	train-normal,1.0:35.4726	test-normal,1.0:36.6885
# [0]	train-normal,1.0:1102.14	test-normal,1.0:128.15
# [1]	train-normal,1.0:964.348	test-normal,1.0:110.647
# [2]	train-normal,1.0:847.579	test-normal,1.0:96.3085
# [3]	train-normal,1.0:746.641	test-normal,1.0:83.9158
# [4]	train-normal,1.0:661.1	test-normal,1.0:73.5979
# [5]	train-normal,1.0:587.744	test-normal,1.0:65.1332
# [6]	train-normal,1.0:524.257	test-normal,1.0:57.8688
# [7]	train-normal,1.0:470.972	test-normal,1.0:51.9534
# [8]	train-normal,1.0:424.178	test-normal,1.0:47.0298
# [9]	train-normal,1.0:382.251	test-normal,1.0:42.6211
# [10]	train-normal,1.0:346.35	test-normal,1.0:38.8126
# [11]	train-normal,1.0:314.576	test-normal,1.0:35.4113
# [12]	train-normal,1.0:288.161	test-normal,1.0:32.7335
# [13]	train-normal,1.0:262.832	test-normal,1.0:30.1019
# [14]	train-normal,1.0:241.495	test-normal,1.0:28.0389
# [15]	train-normal,1.0:222.318	test-normal,1.0:26.4489
# [16]	train-normal,1.0:205.916	test-normal,1.0:25.1383
# [17]	train-normal,1.0:189.622	test-normal,1.0:23.7321
# [18]	train-normal,1.0:176.313	test-normal,1.0:22.5104
# [19]	train-normal,1.0:164.175	test-normal,1.0:21.3165
# [20]	train-normal,1.0:153.036	test-normal,1.0:20.2863
# [21]	train-normal,1.0:142.896	test-normal,1.0:19.5119
# [22]	train-normal,1.0:134.083	test-normal,1.0:18.7818
# [23]	train-normal,1.0:126.16	test-normal,1.0:18.1979
# [24]	train-normal,1.0:118.758	test-normal,1.0:17.6281
# [25]	train-normal,1.0:111.779	test-normal,1.0:17.2011
# [26]	train-normal,1.0:105.714	test-normal,1.0:16.6845
# [27]	train-normal,1.0:100.319	test-normal,1.0:16.2237
# [28]	train-normal,1.0:94.8622	test-normal,1.0:15.8974
# [29]	train-normal,1.0:90.8647	test-normal,1.0:15.7578
# [30]	train-normal,1.0:86.2525	test-normal,1.0:15.2944
# [31]	train-normal,1.0:82.5162	test-normal,1.0:14.9859
# [32]	train-normal,1.0:78.8138	test-normal,1.0:15.1124
# [33]	train-normal,1.0:75.5392	test-normal,1.0:14.9385
# [34]	train-normal,1.0:72.4527	test-normal,1.0:14.5731
# [35]	train-normal,1.0:68.9669	test-normal,1.0:14.4656
# [36]	train-normal,1.0:66.668	test-normal,1.0:14.3589
# [37]	train-normal,1.0:64.4822	test-normal,1.0:14.4601
# [38]	train-normal,1.0:62.4075	test-normal,1.0:14.5615
# [39]	train-normal,1.0:60.3974	test-normal,1.0:14.5374
# [40]	train-normal,1.0:58.5635	test-normal,1.0:14.609
# [41]	train-normal,1.0:56.7995	test-normal,1.0:14.6614
# [42]	train-normal,1.0:53.8315	test-normal,1.0:14.6706
# [43]	train-normal,1.0:52.3276	test-normal,1.0:14.7336
# [44]	train-normal,1.0:50.3545	test-normal,1.0:14.6923
# [45]	train-normal,1.0:48.6383	test-normal,1.0:14.8703
# [46]	train-normal,1.0:46.7932	test-normal,1.0:14.9127
# [47]	train-normal,1.0:45.1142	test-normal,1.0:14.7417
# [48]	train-normal,1.0:43.6721	test-normal,1.0:14.8381
# [49]	train-normal,1.0:42.3761	test-normal,1.0:14.8315
# [0]	train-normal,1.0:1018.86	test-normal,1.0:215.473
# [1]	train-normal,1.0:890.099	test-normal,1.0:192.153
# [2]	train-normal,1.0:780.56	test-normal,1.0:173.486
# [3]	train-normal,1.0:685.904	test-normal,1.0:156.308
# [4]	train-normal,1.0:606.025	test-normal,1.0:141.564
# [5]	train-normal,1.0:537.122	test-normal,1.0:128.208
# [6]	train-normal,1.0:476.986	test-normal,1.0:116.781
# [7]	train-normal,1.0:425.142	test-normal,1.0:106.635
# [8]	train-normal,1.0:380.979	test-normal,1.0:98.1351
# [9]	train-normal,1.0:342.509	test-normal,1.0:90.6008
# [10]	train-normal,1.0:308.202	test-normal,1.0:84.3566
# [11]	train-normal,1.0:279.236	test-normal,1.0:78.6989
# [12]	train-normal,1.0:253.603	test-normal,1.0:73.7199
# [13]	train-normal,1.0:230.381	test-normal,1.0:69.8297
# [14]	train-normal,1.0:210.829	test-normal,1.0:66.126
# [15]	train-normal,1.0:193.438	test-normal,1.0:62.3151
# [16]	train-normal,1.0:177.957	test-normal,1.0:59.552
# [17]	train-normal,1.0:164.357	test-normal,1.0:56.5683
# [18]	train-normal,1.0:152.055	test-normal,1.0:54.251
# [19]	train-normal,1.0:141.149	test-normal,1.0:52.3778
# [20]	train-normal,1.0:132.085	test-normal,1.0:50.1489
# [21]	train-normal,1.0:123.667	test-normal,1.0:48.2203
# [22]	train-normal,1.0:115.887	test-normal,1.0:46.3564
# [23]	train-normal,1.0:109.114	test-normal,1.0:44.6239
# [24]	train-normal,1.0:101.86	test-normal,1.0:43.9325
# [25]	train-normal,1.0:96.5479	test-normal,1.0:42.5395
# [26]	train-normal,1.0:90.3197	test-normal,1.0:42.0479
# [27]	train-normal,1.0:85.4655	test-normal,1.0:40.9048
# [28]	train-normal,1.0:81.5583	test-normal,1.0:39.7201
# [29]	train-normal,1.0:77.0843	test-normal,1.0:39.4306
# [30]	train-normal,1.0:73.6016	test-normal,1.0:38.7452
# [31]	train-normal,1.0:69.4748	test-normal,1.0:38.2387
# [32]	train-normal,1.0:66.3591	test-normal,1.0:37.5459
# [33]	train-normal,1.0:63.2448	test-normal,1.0:36.9901
# [34]	train-normal,1.0:61.0243	test-normal,1.0:36.426
# [35]	train-normal,1.0:58.4758	test-normal,1.0:35.9597
# [36]	train-normal,1.0:55.9981	test-normal,1.0:35.9132
# [37]	train-normal,1.0:53.7076	test-normal,1.0:36.0688
# [38]	train-normal,1.0:51.8592	test-normal,1.0:35.4151
# [39]	train-normal,1.0:49.9329	test-normal,1.0:35.7734
# [40]	train-normal,1.0:47.9498	test-normal,1.0:36.0512
# [41]	train-normal,1.0:45.9803	test-normal,1.0:35.4849
# [42]	train-normal,1.0:43.6971	test-normal,1.0:35.334
# [43]	train-normal,1.0:41.9835	test-normal,1.0:35.127
# [44]	train-normal,1.0:40.7248	test-normal,1.0:35.1883
# [45]	train-normal,1.0:39.2912	test-normal,1.0:35.2059
# [46]	train-normal,1.0:38.0864	test-normal,1.0:35.3941
# [47]	train-normal,1.0:36.6697	test-normal,1.0:35.3895
# [48]	train-normal,1.0:35.7432	test-normal,1.0:35.2021
# [49]	train-normal,1.0:34.3817	test-normal,1.0:34.8827

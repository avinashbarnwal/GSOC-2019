# %%
import xgboost
import pandas            as pd
import numpy             as np
import matplotlib.pyplot as plt
import random

# %%
def getInputOutputFolder(fileFlag=None):
    f  = open("data_file.txt", "r")
    i  = 0
    for l in f.readlines():
        if fileFlag<32:
            if i==fileFlag:
                foldName = l[:-1]
        if fileFlag==32:
            if i==fileFlag:
                foldName = l
        
        i = i+1
    f.close()
    dataNameSplit = foldName.split("/")
    inputFileName  = '../../data/'+ dataNameSplit[1]+'/inputs.csv'
    outputFileName = '../../data/'+ dataNameSplit[1]+'/outputs.csv'
    foldName       = '../../'+foldName
    return inputFileName,outputFileName,foldName,dataNameSplit[1]

# %%
# Input the File Number
# Not Working - 17,18,19,20,21,22,23,24,25
fileFlag = 2
inputFileName,outputFileName,foldName,dataName = getInputOutputFolder(fileFlag)
print(inputFileName)
print(outputFileName)
print(foldName)
print(dataName)
# Out:
# ../../data/H3K27ac-H3K4me3_TDHAM_BP/inputs.csv
# ../../data/H3K27ac-H3K4me3_TDHAM_BP/outputs.csv
# ../../data/H3K27ac-H3K4me3_TDHAM_BP/cv/equal_labels/folds.csv
# H3K27ac-H3K4me3_TDHAM_BP

# %%
input      = pd.read_csv(inputFileName)
label      = pd.read_csv(outputFileName)
folds      = pd.read_csv(foldName)
folds_iter = folds['fold'].unique()
print(folds_iter)
input.replace([np.inf, -np.inf], np.nan,inplace=True)
# Out:
# [4 1 3 2]

# %%
colnames       = input.columns.values
colnamesSeries = input.isna().sum()
nullColnames   = list(colnamesSeries.index[colnamesSeries>0].values)
nullColnames.append('sequenceID')
colnames       = [x for x in colnames if x not in nullColnames]

# %%
def chart_creation_xgboost(res,chart_title,chart_name,distribution):
    
    distributionCol = distribution + ",1.0"
    min_valid = round(np.min(res['test'][distributionCol]),4)
    min_train = round(np.min(res['train'][distributionCol]),4)
    min_iter  = round(np.nanargmin(res['test'][distributionCol]),0)

    textstr = '\n'.join((
                    'Min Train = %.2f' % (min_train, ),
                    'Min Valid = %.2f' % (min_valid, ),
                    'Min Iter  = %.2f' % (min_iter, )))

    props = dict(boxstyle='round', facecolor='wheat', alpha=0.5,edgecolor="black")
    
    fig,ax1       = plt.subplots()
    ax2           = ax1.twinx()

    ln1 = ax1.plot(res['train'][distributionCol],color='blue',label='Training')
    ln2 = ax2.plot(res['test'][distributionCol],color='orange',label='Validation')
    
    lns = ln1 + ln2
    
    labs = [l.get_label() for l in lns]
    ax1.legend(lns, labs, loc='lower left',fancybox='round', facecolor='wheat',fontsize=8)
    
    ax1.set_xlabel("Number of Iterations(Trees)")
    ax1.set_ylabel("Training Negative Likelihood(Loss)")
    ax2.set_ylabel("Validation Negative Likelihood(Loss)")
    ax2.text(0.7, 0.90, textstr, transform=ax1.transAxes, fontsize=8,
        verticalalignment='top', bbox=props)
    plt.title(chart_title)
    plt.show()
    fig.savefig(chart_name)
    
def generate_result(X,y_lower,y_higher,params,X_val=None,y_lower_val=None,y_higher_val=None):
    
    res    = {}
    dtrain = xgboost.DMatrix(X)
    dtrain.set_float_info("label_lower_bound",y_lower)
    dtrain.set_float_info("label_upper_bound",y_higher)
    
    dtest  = xgboost.DMatrix(X_val)
    dtest.set_float_info("label_lower_bound",y_lower_val)
    dtest.set_float_info("label_upper_bound",y_higher_val)
    
    bst    = xgboost.train(params,dtrain,num_boost_round=100,evals=[(dtrain,"train"),(dtest,"test")],evals_result=res)
    return res

# %%
for i in folds_iter:
    
    distribution    = 'extreme'
    distributionCol = 'extreme,1.0'
    test_fold    = i
    test_id      = folds[folds["fold"]==i]['sequenceID']
    train_id     = folds[folds["fold"]!=i]['sequenceID']
    nullId       = label[(label['min.log.lambda']==-float('inf'))&(label['max.log.lambda']==float('inf'))]['sequenceID']
    X            = input[input['sequenceID'].isin(train_id)&(~input['sequenceID'].isin(nullId))]
    X_val        = input[input['sequenceID'].isin(test_id)&(~input['sequenceID'].isin(nullId))]
    
    X            = X[colnames]
    X_val        = X_val[colnames]
    y_label      = label[label['sequenceID'].isin(train_id)&(~label['sequenceID'].isin(nullId))]
    y_label_test = label[label['sequenceID'].isin(test_id)&(~label['sequenceID'].isin(nullId))]
    
    y_lower      = np.array(list(map(lambda x: x if x == float('inf') or x == -float('inf') else np.exp(x),y_label['min.log.lambda'])))
    y_higher     = np.array(list(map(lambda x: x if x == float('inf') or x == -float('inf') else np.exp(x),y_label['max.log.lambda'])))
    y_lower_val  = np.array(list(map(lambda x: x if x == float('inf') or x == -float('inf') else np.exp(x),y_label_test['min.log.lambda'])))
    y_higher_val = np.array(list(map(lambda x: x if x == float('inf') or x == -float('inf') else np.exp(x),y_label_test['max.log.lambda'])))
    
    data_name    = dataName
    title        = 'Loss=LogLoss,Data='+data_name+' Distribution= '+distribution+' Test Fold='+str(test_fold)
    file_name    = title+'.png'
    
    eval_metric  = 'aft-nloglik@'+distributionCol
    params = {'learning_rate':0.1, 'aft_noise_distribution' : distribution, 'aft_sigma': 1.0,'eval_metric':eval_metric,'objective':"aft:survival"}
    bst    = generate_result(X,y_lower,y_higher,params,X_val,y_lower_val,y_higher_val)
    chart_creation_xgboost(bst,title,file_name,distribution)
# Out:
# [0]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [1]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [2]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [3]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [4]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [5]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [6]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [7]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [8]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [9]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [10]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [11]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [12]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [13]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [14]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [15]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [16]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [17]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [18]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [19]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [20]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [21]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [22]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [23]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [24]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [25]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [26]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [27]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [28]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [29]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [30]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [31]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [32]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [33]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [34]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [35]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [36]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [37]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [38]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [39]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [40]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [41]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [42]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [43]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [44]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [45]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [46]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [47]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [48]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [49]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [50]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [51]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [52]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [53]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [54]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [55]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [56]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [57]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [58]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [59]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [60]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [61]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [62]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [63]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [64]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [65]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [66]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [67]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [68]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [69]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [70]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [71]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [72]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [73]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [74]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [75]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [76]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [77]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [78]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [79]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [80]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [81]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [82]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [83]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [84]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [85]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [86]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [87]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [88]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [89]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [90]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [91]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [92]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [93]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [94]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [95]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [96]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [97]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [98]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [99]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [0]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [1]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [2]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [3]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [4]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [5]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [6]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [7]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [8]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [9]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [10]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [11]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [12]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [13]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [14]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [15]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [16]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [17]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [18]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [19]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [20]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [21]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [22]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [23]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [24]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [25]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [26]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [27]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [28]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [29]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [30]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [31]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [32]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [33]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [34]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [35]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [36]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [37]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [38]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [39]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [40]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [41]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [42]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [43]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [44]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [45]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [46]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [47]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [48]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [49]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [50]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [51]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [52]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [53]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [54]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [55]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [56]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [57]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [58]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [59]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [60]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [61]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [62]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [63]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [64]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [65]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [66]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [67]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [68]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [69]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [70]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [71]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [72]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [73]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [74]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [75]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [76]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [77]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [78]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [79]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [80]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [81]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [82]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [83]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [84]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [85]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [86]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [87]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [88]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [89]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [90]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [91]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [92]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [93]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [94]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [95]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [96]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [97]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [98]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [99]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [0]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [1]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [2]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [3]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [4]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [5]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [6]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [7]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [8]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [9]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [10]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [11]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [12]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [13]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [14]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [15]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [16]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [17]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [18]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [19]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [20]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [21]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [22]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [23]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [24]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [25]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [26]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [27]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [28]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [29]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [30]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [31]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [32]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [33]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [34]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [35]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [36]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [37]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [38]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [39]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [40]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [41]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [42]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [43]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [44]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [45]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [46]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [47]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [48]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [49]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [50]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [51]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [52]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [53]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [54]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [55]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [56]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [57]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [58]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [59]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [60]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [61]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [62]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [63]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [64]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [65]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [66]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [67]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [68]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [69]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [70]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [71]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [72]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [73]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [74]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [75]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [76]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [77]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [78]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [79]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [80]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [81]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [82]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [83]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [84]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [85]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [86]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [87]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [88]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [89]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [90]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [91]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [92]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [93]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [94]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [95]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [96]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [97]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [98]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [99]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [0]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [1]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [2]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [3]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [4]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [5]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [6]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [7]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [8]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [9]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [10]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [11]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [12]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [13]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [14]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [15]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [16]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [17]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [18]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [19]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [20]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [21]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [22]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [23]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [24]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [25]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [26]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [27]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [28]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [29]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [30]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [31]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [32]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [33]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [34]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [35]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [36]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [37]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [38]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [39]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [40]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [41]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [42]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [43]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [44]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [45]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [46]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [47]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [48]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [49]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [50]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [51]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [52]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [53]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [54]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [55]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [56]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [57]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [58]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [59]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [60]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [61]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [62]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [63]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [64]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [65]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [66]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [67]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [68]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [69]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [70]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [71]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [72]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [73]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [74]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [75]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [76]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [77]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [78]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [79]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [80]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [81]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [82]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [83]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [84]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [85]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [86]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [87]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [88]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [89]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [90]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [91]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [92]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [93]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [94]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [95]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [96]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [97]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [98]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [99]	train-extreme,1.0:inf	test-extreme,1.0:inf

# %%
data      = pd.read_csv('simulate_survival.csv')
rows,cols = data.shape[0],data.shape[1]
list1     = list(np.arange(rows))
sample    = random.sample(list1, 800)

# %%
train = data[data.index.isin(sample)]
test  = data[~data.index.isin(sample)]

# %%
X            = train[['x1','x2','x3']]
X_val        = test[['x1','x2','x3']]
y_lower      = train['left']
y_lower_val  = test['left']
y_higher     = train['right']
y_higher_val = test['right']

# %%
dataName    = 'simulate'
data_name   = dataName
title       = 'Loss=LogLoss,Data='+data_name+' Test Fold='+str(test_fold)
file_name   = title+'.png'
    
params = {'learning_rate':1, 'aft_noise_distribution' : 'extreme', 'aft_sigma': 1.0,'eval_metric':'aft-nloglik@extreme,1.0','objective':"aft:survival"}
bst    = generate_result(X,y_lower,y_higher,params,X_val,y_lower_val,y_higher_val)
chart_creation_xgboost(bst,title,file_name)
# Out:
# [0]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [1]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [2]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [3]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [4]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [5]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [6]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [7]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [8]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [9]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [10]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [11]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [12]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [13]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [14]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [15]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [16]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [17]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [18]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [19]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [20]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [21]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [22]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [23]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [24]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [25]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [26]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [27]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [28]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [29]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [30]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [31]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [32]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [33]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [34]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [35]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [36]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [37]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [38]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [39]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [40]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [41]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [42]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [43]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [44]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [45]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [46]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [47]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [48]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [49]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [50]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [51]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [52]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [53]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [54]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [55]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [56]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [57]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [58]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [59]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [60]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [61]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [62]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [63]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [64]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [65]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [66]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [67]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [68]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [69]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [70]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [71]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [72]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [73]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [74]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [75]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [76]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [77]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [78]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [79]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [80]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [81]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [82]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [83]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [84]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [85]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [86]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [87]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [88]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [89]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [90]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [91]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [92]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [93]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [94]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [95]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [96]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [97]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [98]	train-extreme,1.0:inf	test-extreme,1.0:inf
# [99]	train-extreme,1.0:inf	test-extreme,1.0:inf
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-afb49d9c1f59> in <module>
#       6 params = {'learning_rate':1, 'aft_noise_distribution' : 'extreme', 'aft_sigma': 1.0,'eval_metric':'aft-nloglik@extreme,1.0','objective':"aft:survival"}
#       7 bst    = generate_result(X,y_lower,y_higher,params,X_val,y_lower_val,y_higher_val)
# ----> 8 chart_creation_xgboost(bst,title,file_name)
#
# TypeError: chart_creation_xgboost() missing 1 required positional argument: 'distribution'

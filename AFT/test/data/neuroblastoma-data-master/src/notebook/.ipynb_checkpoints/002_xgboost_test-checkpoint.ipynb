# %%
import xgboost
import pandas            as pd
import numpy             as np
import matplotlib.pyplot as plt
import random

# %%
def getInputOutputFolder(fileFlag=None):
    f  = open("data_file.txt", "r")
    i  = 0
    for l in f.readlines():
        if fileFlag<32:
            if i==fileFlag:
                foldName = l[:-1]
        if fileFlag==32:
            if i==fileFlag:
                foldName = l
        
        i = i+1
    f.close()
    dataNameSplit = foldName.split("/")
    inputFileName  = '../../data/'+ dataNameSplit[1]+'/inputs.csv'
    outputFileName = '../../data/'+ dataNameSplit[1]+'/outputs.csv'
    foldName       = '../../'+foldName
    return inputFileName,outputFileName,foldName,dataNameSplit[1]

# %%
# Input the File Number
# Not Working - 17,18,19,20,21,22,23,24,25
fileFlag = 0
inputFileName,outputFileName,foldName,dataName = getInputOutputFolder(fileFlag)
print(inputFileName)
print(outputFileName)
print(foldName)
print(dataName)
# Out:
# ../../data/ATAC_JV_adipose/inputs.csv
# ../../data/ATAC_JV_adipose/outputs.csv
# ../../data/ATAC_JV_adipose/cv/equal_labels/folds.csv
# ATAC_JV_adipose

# %%
input      = pd.read_csv(inputFileName)
label      = pd.read_csv(outputFileName)
folds      = pd.read_csv(foldName)
folds_iter = folds['fold'].unique()
print(folds_iter)
input.replace([np.inf, -np.inf], np.nan,inplace=True)
# Out:
# [2 4 1 3]

# %%
colnames       = input.columns.values
colnamesSeries = input.isna().sum()
nullColnames   = list(colnamesSeries.index[colnamesSeries>0].values)
nullColnames.append('sequenceID')
colnames       = [x for x in colnames if x not in nullColnames]

# %%
def chart_creation_xgboost(res,chart_title,chart_name,distribution,parameter):
    
    distributionCol = distribution + ","+str(parameter)
    min_valid = round(np.min(res['test'][distributionCol]),4)
    min_train = round(np.min(res['train'][distributionCol]),4)
    min_iter  = round(np.nanargmin(res['test'][distributionCol]),0)

    textstr = '\n'.join((
                    'Min Train = %.2f' % (min_train, ),
                    'Min Valid = %.2f' % (min_valid, ),
                    'Min Iter  = %.2f' % (min_iter, )))

    props = dict(boxstyle='round', facecolor='wheat', alpha=0.5,edgecolor="black")
    
    fig,ax1       = plt.subplots()
    ax2           = ax1.twinx()

    ln1 = ax1.plot(res['train'][distributionCol],color='blue',label='Training')
    ln2 = ax2.plot(res['test'][distributionCol],color='orange',label='Validation')
    
    lns = ln1 + ln2
    
    labs = [l.get_label() for l in lns]
    ax1.legend(lns, labs, loc='lower left',fancybox='round', facecolor='wheat',fontsize=8)
    
    ax1.set_xlabel("Number of Iterations(Trees)")
    ax1.set_ylabel("Training Negative Likelihood(Loss)")
    ax2.set_ylabel("Validation Negative Likelihood(Loss)")
    ax2.text(0.7, 0.90, textstr, transform=ax1.transAxes, fontsize=8,
        verticalalignment='top', bbox=props)
    plt.title(chart_title)
    plt.show()
    fig.savefig(chart_name)
    
def generate_result(X,y_lower,y_higher,params,X_val=None,y_lower_val=None,y_higher_val=None):
    
    res    = {}
    dtrain = xgboost.DMatrix(X)
    dtrain.set_float_info("label_lower_bound",y_lower)
    dtrain.set_float_info("label_upper_bound",y_higher)
    
    dtest  = xgboost.DMatrix(X_val)
    dtest.set_float_info("label_lower_bound",y_lower_val)
    dtest.set_float_info("label_upper_bound",y_higher_val)
    
    bst    = xgboost.train(params,dtrain,num_boost_round=100,evals=[(dtrain,"train"),(dtest,"test")],evals_result=res)
    return res

# %%
def calculateSummaryStats(data):
    data     = list(filter(lambda x : x not in [float('inf'),-float('inf')],data))
    std      = np.std(data)
    avg      = np.mean(data)
    return std,avg

# %%
for i in folds_iter:
    
    distribution = 'normal'
    test_fold    = i
    test_id      = folds[folds["fold"]==i]['sequenceID']
    train_id     = folds[folds["fold"]!=i]['sequenceID']
    
    nullId       = label[(label['min.log.lambda']==-float('inf'))&(label['max.log.lambda']==float('inf'))]['sequenceID']
    X            = input[input['sequenceID'].isin(train_id)&(~input['sequenceID'].isin(nullId))]
    X_val        = input[input['sequenceID'].isin(test_id)&(~input['sequenceID'].isin(nullId))]
    X            = X[colnames]
    X_val        = X_val[colnames]
    y_label      = label[label['sequenceID'].isin(train_id)&(~label['sequenceID'].isin(nullId))]
    y_label_test = label[label['sequenceID'].isin(test_id)&(~label['sequenceID'].isin(nullId))]
    
    std_higher,avg_higher = calculateSummaryStats(y_label['max.log.lambda'].copy())
    std_lower,avg_lower   = calculateSummaryStats(y_label['min.log.lambda'].copy())
    
    std_cal        = round((std_higher+std_lower)/2,2)
    sigma          = std_cal
    base_score_cal = (avg_higher+avg_lower)/2
    base_score     = base_score_cal
    
    distributionCol = 'normal,' + str(sigma)
    y_lower      = np.array(list(map(lambda x: x if x == float('inf') else np.exp(x),y_label['min.log.lambda'])))
    y_higher     = np.array(list(map(lambda x: x if x == float('inf') else np.exp(x),y_label['max.log.lambda'])))
    y_lower_val  = np.array(list(map(lambda x: x if x == float('inf') else np.exp(x),y_label_test['min.log.lambda'])))
    y_higher_val = np.array(list(map(lambda x: x if x == float('inf') else np.exp(x),y_label_test['max.log.lambda'])))
    
    data_name    = dataName
    title        = 'Loss=LogLoss,Data='+data_name+' Distribution= '+distribution+' Test Fold='+str(test_fold)
    file_name    = title+'.png'
    
    eval_metric  = 'aft-nloglik@'+distributionCol
    
    params = {'learning_rate':0.1, 'aft_noise_distribution' : distribution, 'aft_sigma': sigma,'eval_metric':eval_metric,'base_score':base_score,'objective':"aft:survival"}
    bst    = generate_result(X,y_lower,y_higher,params,X_val,y_lower_val,y_higher_val)
    chart_creation_xgboost(bst,title,file_name,distribution,sigma)
# Out:
# [0]	train-normal,1.35:inf	test-normal,1.35:1510.89
# [1]	train-normal,1.35:inf	test-normal,1.35:1278.48
# [2]	train-normal,1.35:inf	test-normal,1.35:1082.72
# [3]	train-normal,1.35:2403.37	test-normal,1.35:922.417
# [4]	train-normal,1.35:2064.87	test-normal,1.35:791.095
# [5]	train-normal,1.35:1785.91	test-normal,1.35:689.188
# [6]	train-normal,1.35:1555.49	test-normal,1.35:597.979
# [7]	train-normal,1.35:1366.83	test-normal,1.35:540.89
# [8]	train-normal,1.35:1211	test-normal,1.35:488.49
# [9]	train-normal,1.35:1080.64	test-normal,1.35:433.966
# [10]	train-normal,1.35:973.315	test-normal,1.35:400.698
# [11]	train-normal,1.35:883.276	test-normal,1.35:364.132
# [12]	train-normal,1.35:808.836	test-normal,1.35:340.683
# [13]	train-normal,1.35:748.096	test-normal,1.35:318.609
# [14]	train-normal,1.35:696.752	test-normal,1.35:298.545
# [15]	train-normal,1.35:654.965	test-normal,1.35:286.116
# [16]	train-normal,1.35:619.378	test-normal,1.35:271.055
# [17]	train-normal,1.35:588.533	test-normal,1.35:262.41
# [18]	train-normal,1.35:563.805	test-normal,1.35:251.629
# [19]	train-normal,1.35:541.875	test-normal,1.35:245.545
# [20]	train-normal,1.35:523.597	test-normal,1.35:236.52
# [21]	train-normal,1.35:507.773	test-normal,1.35:231.673
# [22]	train-normal,1.35:494.75	test-normal,1.35:226.78
# [23]	train-normal,1.35:483.357	test-normal,1.35:222.476
# [24]	train-normal,1.35:474.06	test-normal,1.35:217.737
# [25]	train-normal,1.35:465.542	test-normal,1.35:213.812
# [26]	train-normal,1.35:457.972	test-normal,1.35:210.505
# [27]	train-normal,1.35:452.249	test-normal,1.35:207.132
# [28]	train-normal,1.35:447.285	test-normal,1.35:205.625
# [29]	train-normal,1.35:442.631	test-normal,1.35:203.631
# [30]	train-normal,1.35:439.06	test-normal,1.35:201.242
# [31]	train-normal,1.35:435.101	test-normal,1.35:199.38
# [32]	train-normal,1.35:432.065	test-normal,1.35:197.504
# [33]	train-normal,1.35:429.349	test-normal,1.35:195.602
# [34]	train-normal,1.35:426.946	test-normal,1.35:194.441
# [35]	train-normal,1.35:424.778	test-normal,1.35:193.307
# [36]	train-normal,1.35:422.798	test-normal,1.35:192.236
# [37]	train-normal,1.35:420.886	test-normal,1.35:191.427
# [38]	train-normal,1.35:419.309	test-normal,1.35:190.983
# [39]	train-normal,1.35:417.529	test-normal,1.35:189.867
# [40]	train-normal,1.35:416.133	test-normal,1.35:189.6
# [41]	train-normal,1.35:414.756	test-normal,1.35:188.697
# [42]	train-normal,1.35:413.613	test-normal,1.35:187.953
# [43]	train-normal,1.35:412.686	test-normal,1.35:187.273
# [44]	train-normal,1.35:411.934	test-normal,1.35:186.762
# [45]	train-normal,1.35:410.964	test-normal,1.35:186.324
# [46]	train-normal,1.35:410.321	test-normal,1.35:185.376
# [47]	train-normal,1.35:409.241	test-normal,1.35:184.745
# [48]	train-normal,1.35:408.573	test-normal,1.35:184.708
# [49]	train-normal,1.35:407.574	test-normal,1.35:184.35
# [50]	train-normal,1.35:406.898	test-normal,1.35:183.864
# [51]	train-normal,1.35:406.199	test-normal,1.35:183.545
# [52]	train-normal,1.35:405.888	test-normal,1.35:183.512
# [53]	train-normal,1.35:405.415	test-normal,1.35:183.446
# [54]	train-normal,1.35:405.051	test-normal,1.35:183.423
# [55]	train-normal,1.35:404.557	test-normal,1.35:183.172
# [56]	train-normal,1.35:404.163	test-normal,1.35:183.169
# [57]	train-normal,1.35:403.679	test-normal,1.35:183.494
# [58]	train-normal,1.35:403.361	test-normal,1.35:183.647
# [59]	train-normal,1.35:403.014	test-normal,1.35:183.56
# [60]	train-normal,1.35:402.718	test-normal,1.35:183.596
# [61]	train-normal,1.35:402.423	test-normal,1.35:183.583
# [62]	train-normal,1.35:402.171	test-normal,1.35:183.437
# [63]	train-normal,1.35:401.872	test-normal,1.35:183.249
# [64]	train-normal,1.35:401.785	test-normal,1.35:183.544
# [65]	train-normal,1.35:401.403	test-normal,1.35:183.51
# [66]	train-normal,1.35:401.325	test-normal,1.35:183.573
# [67]	train-normal,1.35:401.043	test-normal,1.35:183.514
# [68]	train-normal,1.35:400.88	test-normal,1.35:183.608
# [69]	train-normal,1.35:400.65	test-normal,1.35:183.609
# [70]	train-normal,1.35:400.456	test-normal,1.35:183.691
# [71]	train-normal,1.35:400.158	test-normal,1.35:183.634
# [72]	train-normal,1.35:399.897	test-normal,1.35:183.555
# [73]	train-normal,1.35:399.54	test-normal,1.35:183.616
# [74]	train-normal,1.35:399.392	test-normal,1.35:183.708
# [75]	train-normal,1.35:399.277	test-normal,1.35:183.809
# [76]	train-normal,1.35:398.672	test-normal,1.35:183.795
# [77]	train-normal,1.35:398.589	test-normal,1.35:183.781
# [78]	train-normal,1.35:398.321	test-normal,1.35:183.717
# [79]	train-normal,1.35:398.198	test-normal,1.35:183.796
# [80]	train-normal,1.35:398.014	test-normal,1.35:183.938
# [81]	train-normal,1.35:397.733	test-normal,1.35:183.986
# [82]	train-normal,1.35:397.61	test-normal,1.35:184.569
# [83]	train-normal,1.35:397.506	test-normal,1.35:184.582
# [84]	train-normal,1.35:397.387	test-normal,1.35:184.521
# [85]	train-normal,1.35:397.072	test-normal,1.35:184.319
# [86]	train-normal,1.35:396.886	test-normal,1.35:184.219
# [87]	train-normal,1.35:396.746	test-normal,1.35:184.295
# [88]	train-normal,1.35:396.634	test-normal,1.35:184.327
# [89]	train-normal,1.35:396.411	test-normal,1.35:184.271
# [90]	train-normal,1.35:396.347	test-normal,1.35:184.146
# [91]	train-normal,1.35:396.148	test-normal,1.35:184.142
# [92]	train-normal,1.35:396.005	test-normal,1.35:184.091
# [93]	train-normal,1.35:395.881	test-normal,1.35:184.218
# [94]	train-normal,1.35:395.803	test-normal,1.35:184.404
# [95]	train-normal,1.35:395.569	test-normal,1.35:184.53
# [96]	train-normal,1.35:395.321	test-normal,1.35:184.588
# [97]	train-normal,1.35:395.175	test-normal,1.35:184.673
# [98]	train-normal,1.35:394.978	test-normal,1.35:184.706
# [99]	train-normal,1.35:394.933	test-normal,1.35:184.775
# [0]	train-normal,1.27:inf	test-normal,1.27:inf
# [1]	train-normal,1.27:inf	test-normal,1.27:1577.65
# [2]	train-normal,1.27:inf	test-normal,1.27:1355.06
# [3]	train-normal,1.27:inf	test-normal,1.27:1184.18
# [4]	train-normal,1.27:2139.14	test-normal,1.27:1030.32
# [5]	train-normal,1.27:1833.88	test-normal,1.27:917.245
# [6]	train-normal,1.27:1582.96	test-normal,1.27:814.191
# [7]	train-normal,1.27:1376.84	test-normal,1.27:741.571
# [8]	train-normal,1.27:1206.25	test-normal,1.27:667.081
# [9]	train-normal,1.27:1067.59	test-normal,1.27:612.163
# [10]	train-normal,1.27:952.614	test-normal,1.27:558.215
# [11]	train-normal,1.27:856.725	test-normal,1.27:516.272
# [12]	train-normal,1.27:778.254	test-normal,1.27:483.579
# [13]	train-normal,1.27:713.955	test-normal,1.27:458.252
# [14]	train-normal,1.27:660.278	test-normal,1.27:436.429
# [15]	train-normal,1.27:614.59	test-normal,1.27:411.765
# [16]	train-normal,1.27:575.922	test-normal,1.27:397.005
# [17]	train-normal,1.27:543.294	test-normal,1.27:379.803
# [18]	train-normal,1.27:517.132	test-normal,1.27:370.195
# [19]	train-normal,1.27:494.848	test-normal,1.27:359.986
# [20]	train-normal,1.27:475.814	test-normal,1.27:348.865
# [21]	train-normal,1.27:460.168	test-normal,1.27:341.025
# [22]	train-normal,1.27:445.765	test-normal,1.27:332.671
# [23]	train-normal,1.27:434.222	test-normal,1.27:326.996
# [24]	train-normal,1.27:424.155	test-normal,1.27:321.338
# [25]	train-normal,1.27:415.388	test-normal,1.27:313.574
# [26]	train-normal,1.27:408.048	test-normal,1.27:307.507
# [27]	train-normal,1.27:401.682	test-normal,1.27:301.416
# [28]	train-normal,1.27:395.948	test-normal,1.27:296.608
# [29]	train-normal,1.27:390.792	test-normal,1.27:292.985
# [30]	train-normal,1.27:386.31	test-normal,1.27:289.065
# [31]	train-normal,1.27:382.766	test-normal,1.27:287.377
# [32]	train-normal,1.27:379.648	test-normal,1.27:284.541
# [33]	train-normal,1.27:377.107	test-normal,1.27:283.568
# [34]	train-normal,1.27:374.832	test-normal,1.27:280.825
# [35]	train-normal,1.27:372.896	test-normal,1.27:278.894
# [36]	train-normal,1.27:370.794	test-normal,1.27:277.05
# [37]	train-normal,1.27:368.713	test-normal,1.27:275.471
# [38]	train-normal,1.27:367.389	test-normal,1.27:275.308
# [39]	train-normal,1.27:365.901	test-normal,1.27:272.871
# [40]	train-normal,1.27:364.465	test-normal,1.27:272.298
# [41]	train-normal,1.27:363.212	test-normal,1.27:271.565
# [42]	train-normal,1.27:362.36	test-normal,1.27:270.754
# [43]	train-normal,1.27:361.183	test-normal,1.27:270.392
# [44]	train-normal,1.27:360.353	test-normal,1.27:269.467
# [45]	train-normal,1.27:359.239	test-normal,1.27:268.766
# [46]	train-normal,1.27:358.336	test-normal,1.27:268.217
# [47]	train-normal,1.27:357.889	test-normal,1.27:267.586
# [48]	train-normal,1.27:357.403	test-normal,1.27:267.498
# [49]	train-normal,1.27:356.847	test-normal,1.27:267.07
# [50]	train-normal,1.27:356.241	test-normal,1.27:267.364
# [51]	train-normal,1.27:355.852	test-normal,1.27:267.463
# [52]	train-normal,1.27:355.308	test-normal,1.27:267.637
# [53]	train-normal,1.27:354.649	test-normal,1.27:267.248
# [54]	train-normal,1.27:354.174	test-normal,1.27:267.446
# [55]	train-normal,1.27:353.974	test-normal,1.27:268.059
# [56]	train-normal,1.27:353.724	test-normal,1.27:267.555
# [57]	train-normal,1.27:353.004	test-normal,1.27:268.019
# [58]	train-normal,1.27:352.636	test-normal,1.27:267.744
# [59]	train-normal,1.27:352.086	test-normal,1.27:268.038
# [60]	train-normal,1.27:351.617	test-normal,1.27:268.419
# [61]	train-normal,1.27:351.229	test-normal,1.27:268.204
# [62]	train-normal,1.27:350.886	test-normal,1.27:268.971
# [63]	train-normal,1.27:350.55	test-normal,1.27:269.502
# [64]	train-normal,1.27:350.155	test-normal,1.27:269.411
# [65]	train-normal,1.27:349.828	test-normal,1.27:269.543
# [66]	train-normal,1.27:349.549	test-normal,1.27:270.123
# [67]	train-normal,1.27:349.195	test-normal,1.27:270.449
# [68]	train-normal,1.27:348.83	test-normal,1.27:270.898
# [69]	train-normal,1.27:348.603	test-normal,1.27:271.511
# [70]	train-normal,1.27:348.25	test-normal,1.27:272.315
# [71]	train-normal,1.27:347.993	test-normal,1.27:272.418
# [72]	train-normal,1.27:347.792	test-normal,1.27:272.602
# [73]	train-normal,1.27:347.553	test-normal,1.27:272.7
# [74]	train-normal,1.27:347.26	test-normal,1.27:273.183
# [75]	train-normal,1.27:347.139	test-normal,1.27:273
# [76]	train-normal,1.27:347.016	test-normal,1.27:272.325
# [77]	train-normal,1.27:346.937	test-normal,1.27:272.092
# [78]	train-normal,1.27:346.688	test-normal,1.27:272.468
# [79]	train-normal,1.27:346.502	test-normal,1.27:272.519
# [80]	train-normal,1.27:346.417	test-normal,1.27:273.032
# [81]	train-normal,1.27:346.343	test-normal,1.27:272.599
# [82]	train-normal,1.27:346.092	test-normal,1.27:272.821
# [83]	train-normal,1.27:345.877	test-normal,1.27:273.099
# [84]	train-normal,1.27:345.726	test-normal,1.27:273.201
# [85]	train-normal,1.27:345.514	test-normal,1.27:273.203
# [86]	train-normal,1.27:345.453	test-normal,1.27:273.136
# [87]	train-normal,1.27:345.262	test-normal,1.27:273.206
# [88]	train-normal,1.27:345.121	test-normal,1.27:273.453
# [89]	train-normal,1.27:345.008	test-normal,1.27:273.555
# [90]	train-normal,1.27:344.905	test-normal,1.27:273.681
# [91]	train-normal,1.27:344.825	test-normal,1.27:273.501
# [92]	train-normal,1.27:344.758	test-normal,1.27:273.791
# [93]	train-normal,1.27:344.589	test-normal,1.27:273.743
# [94]	train-normal,1.27:344.434	test-normal,1.27:274.008
# [95]	train-normal,1.27:344.313	test-normal,1.27:273.925
# [96]	train-normal,1.27:344.264	test-normal,1.27:274.024
# [97]	train-normal,1.27:344.169	test-normal,1.27:273.966
# [98]	train-normal,1.27:344.033	test-normal,1.27:274.237
# [99]	train-normal,1.27:343.95	test-normal,1.27:274.131
# [0]	train-normal,1.27:inf	test-normal,1.27:inf
# [1]	train-normal,1.27:3718.65	test-normal,1.27:inf
# [2]	train-normal,1.27:3132.43	test-normal,1.27:inf
# [3]	train-normal,1.27:2655.99	test-normal,1.27:inf
# [4]	train-normal,1.27:2263.13	test-normal,1.27:776.51
# [5]	train-normal,1.27:1941.76	test-normal,1.27:668.509
# [6]	train-normal,1.27:1675.82	test-normal,1.27:579.308
# [7]	train-normal,1.27:1455.41	test-normal,1.27:507.475
# [8]	train-normal,1.27:1272.27	test-normal,1.27:448.005
# [9]	train-normal,1.27:1120.66	test-normal,1.27:398.726
# [10]	train-normal,1.27:995.755	test-normal,1.27:352.444
# [11]	train-normal,1.27:891.774	test-normal,1.27:317.908
# [12]	train-normal,1.27:805.569	test-normal,1.27:291.975
# [13]	train-normal,1.27:733.847	test-normal,1.27:267.763
# [14]	train-normal,1.27:674.716	test-normal,1.27:249.186
# [15]	train-normal,1.27:624.701	test-normal,1.27:233.954
# [16]	train-normal,1.27:583.605	test-normal,1.27:221.361
# [17]	train-normal,1.27:549.202	test-normal,1.27:210.709
# [18]	train-normal,1.27:520.39	test-normal,1.27:203.077
# [19]	train-normal,1.27:496.187	test-normal,1.27:194.667
# [20]	train-normal,1.27:475.885	test-normal,1.27:189.341
# [21]	train-normal,1.27:458.584	test-normal,1.27:184.604
# [22]	train-normal,1.27:444.419	test-normal,1.27:180.428
# [23]	train-normal,1.27:432.512	test-normal,1.27:175.725
# [24]	train-normal,1.27:422.204	test-normal,1.27:172.572
# [25]	train-normal,1.27:413.502	test-normal,1.27:170.747
# [26]	train-normal,1.27:406.151	test-normal,1.27:168.578
# [27]	train-normal,1.27:400.055	test-normal,1.27:166.937
# [28]	train-normal,1.27:394.419	test-normal,1.27:165.2
# [29]	train-normal,1.27:389.535	test-normal,1.27:164.229
# [30]	train-normal,1.27:385.463	test-normal,1.27:163.068
# [31]	train-normal,1.27:381.724	test-normal,1.27:162.412
# [32]	train-normal,1.27:378.784	test-normal,1.27:161.481
# [33]	train-normal,1.27:375.958	test-normal,1.27:161.059
# [34]	train-normal,1.27:373.488	test-normal,1.27:160.02
# [35]	train-normal,1.27:371.449	test-normal,1.27:159.555
# [36]	train-normal,1.27:369.329	test-normal,1.27:159.284
# [37]	train-normal,1.27:367.548	test-normal,1.27:158.516
# [38]	train-normal,1.27:366.089	test-normal,1.27:157.694
# [39]	train-normal,1.27:364.581	test-normal,1.27:157.068
# [40]	train-normal,1.27:363.396	test-normal,1.27:156.612
# [41]	train-normal,1.27:362.319	test-normal,1.27:156.361
# [42]	train-normal,1.27:361.278	test-normal,1.27:156.38
# [43]	train-normal,1.27:360.237	test-normal,1.27:156.066
# [44]	train-normal,1.27:359.211	test-normal,1.27:155.633
# [45]	train-normal,1.27:358.22	test-normal,1.27:155.599
# [46]	train-normal,1.27:357.327	test-normal,1.27:155.244
# [47]	train-normal,1.27:356.693	test-normal,1.27:155.022
# [48]	train-normal,1.27:356.02	test-normal,1.27:154.927
# [49]	train-normal,1.27:355.363	test-normal,1.27:154.661
# [50]	train-normal,1.27:354.853	test-normal,1.27:154.535
# [51]	train-normal,1.27:354.368	test-normal,1.27:154.551
# [52]	train-normal,1.27:353.987	test-normal,1.27:154.757
# [53]	train-normal,1.27:353.584	test-normal,1.27:154.567
# [54]	train-normal,1.27:353.264	test-normal,1.27:154.73
# [55]	train-normal,1.27:352.633	test-normal,1.27:154.675
# [56]	train-normal,1.27:352.342	test-normal,1.27:154.883
# [57]	train-normal,1.27:352.026	test-normal,1.27:154.785
# [58]	train-normal,1.27:351.839	test-normal,1.27:154.709
# [59]	train-normal,1.27:351.451	test-normal,1.27:154.598
# [60]	train-normal,1.27:351.179	test-normal,1.27:154.386
# [61]	train-normal,1.27:350.942	test-normal,1.27:154.224
# [62]	train-normal,1.27:350.713	test-normal,1.27:154.233
# [63]	train-normal,1.27:350.529	test-normal,1.27:154.215
# [64]	train-normal,1.27:350.315	test-normal,1.27:154.155
# [65]	train-normal,1.27:350.137	test-normal,1.27:154.107
# [66]	train-normal,1.27:349.882	test-normal,1.27:154.28
# [67]	train-normal,1.27:349.626	test-normal,1.27:154.255
# [68]	train-normal,1.27:349.476	test-normal,1.27:154.245
# [69]	train-normal,1.27:349.038	test-normal,1.27:154.358
# [70]	train-normal,1.27:348.925	test-normal,1.27:154.347
# [71]	train-normal,1.27:348.487	test-normal,1.27:154.367
# [72]	train-normal,1.27:348.327	test-normal,1.27:154.366
# [73]	train-normal,1.27:348.217	test-normal,1.27:154.254
# [74]	train-normal,1.27:347.815	test-normal,1.27:154.311
# [75]	train-normal,1.27:347.476	test-normal,1.27:154.14
# [76]	train-normal,1.27:347.235	test-normal,1.27:154.182
# [77]	train-normal,1.27:347.102	test-normal,1.27:154.114
# [78]	train-normal,1.27:346.735	test-normal,1.27:154.201
# [79]	train-normal,1.27:346.526	test-normal,1.27:154.193
# [80]	train-normal,1.27:346.344	test-normal,1.27:154.217
# [81]	train-normal,1.27:346.218	test-normal,1.27:154.142
# [82]	train-normal,1.27:345.95	test-normal,1.27:154.207
# [83]	train-normal,1.27:345.81	test-normal,1.27:154.211
# [84]	train-normal,1.27:345.83	test-normal,1.27:154.213
# [85]	train-normal,1.27:345.75	test-normal,1.27:154.118
# [86]	train-normal,1.27:345.611	test-normal,1.27:154.182
# [87]	train-normal,1.27:345.521	test-normal,1.27:154.219
# [88]	train-normal,1.27:345.403	test-normal,1.27:154.281
# [89]	train-normal,1.27:345.226	test-normal,1.27:154.337
# [90]	train-normal,1.27:345.177	test-normal,1.27:154.334
# [91]	train-normal,1.27:345.09	test-normal,1.27:154.387
# [92]	train-normal,1.27:345.02	test-normal,1.27:154.332
# [93]	train-normal,1.27:344.872	test-normal,1.27:154.327
# [94]	train-normal,1.27:344.821	test-normal,1.27:154.326
# [95]	train-normal,1.27:344.685	test-normal,1.27:154.399
# [96]	train-normal,1.27:344.641	test-normal,1.27:154.266
# [97]	train-normal,1.27:344.668	test-normal,1.27:154.266
# [98]	train-normal,1.27:344.566	test-normal,1.27:154.345
# [99]	train-normal,1.27:344.478	test-normal,1.27:154.356
# [0]	train-normal,1.26:inf	test-normal,1.26:inf
# [1]	train-normal,1.26:inf	test-normal,1.26:770.168
# [2]	train-normal,1.26:inf	test-normal,1.26:636.502
# [3]	train-normal,1.26:inf	test-normal,1.26:529.158
# [4]	train-normal,1.26:2584.5	test-normal,1.26:442.969
# [5]	train-normal,1.26:2211.91	test-normal,1.26:379.691
# [6]	train-normal,1.26:1903.54	test-normal,1.26:328.125
# [7]	train-normal,1.26:1647.35	test-normal,1.26:285.745
# [8]	train-normal,1.26:1435.78	test-normal,1.26:251.488
# [9]	train-normal,1.26:1262.89	test-normal,1.26:223.687
# [10]	train-normal,1.26:1118.17	test-normal,1.26:202.869
# [11]	train-normal,1.26:998.088	test-normal,1.26:185.175
# [12]	train-normal,1.26:897.397	test-normal,1.26:170.673
# [13]	train-normal,1.26:814.635	test-normal,1.26:159.15
# [14]	train-normal,1.26:744.763	test-normal,1.26:150.856
# [15]	train-normal,1.26:687.713	test-normal,1.26:143.819
# [16]	train-normal,1.26:638.982	test-normal,1.26:139.872
# [17]	train-normal,1.26:598.885	test-normal,1.26:135.912
# [18]	train-normal,1.26:564.738	test-normal,1.26:133.48
# [19]	train-normal,1.26:536.101	test-normal,1.26:132.424
# [20]	train-normal,1.26:511.683	test-normal,1.26:131.941
# [21]	train-normal,1.26:490.582	test-normal,1.26:131.562
# [22]	train-normal,1.26:473.555	test-normal,1.26:131.2
# [23]	train-normal,1.26:459.009	test-normal,1.26:131.37
# [24]	train-normal,1.26:446.351	test-normal,1.26:131.662
# [25]	train-normal,1.26:436.068	test-normal,1.26:132.03
# [26]	train-normal,1.26:427.248	test-normal,1.26:132.821
# [27]	train-normal,1.26:418.909	test-normal,1.26:133.606
# [28]	train-normal,1.26:411.843	test-normal,1.26:134.314
# [29]	train-normal,1.26:405.63	test-normal,1.26:135.048
# [30]	train-normal,1.26:400.347	test-normal,1.26:134.986
# [31]	train-normal,1.26:395.427	test-normal,1.26:135.701
# [32]	train-normal,1.26:391.493	test-normal,1.26:136.799
# [33]	train-normal,1.26:388.296	test-normal,1.26:136.8
# [34]	train-normal,1.26:384.965	test-normal,1.26:136.85
# [35]	train-normal,1.26:382.218	test-normal,1.26:137.568
# [36]	train-normal,1.26:379.552	test-normal,1.26:137.652
# [37]	train-normal,1.26:377.415	test-normal,1.26:137.959
# [38]	train-normal,1.26:375.658	test-normal,1.26:138.517
# [39]	train-normal,1.26:374.073	test-normal,1.26:138.898
# [40]	train-normal,1.26:372.563	test-normal,1.26:139.211
# [41]	train-normal,1.26:370.988	test-normal,1.26:138.921
# [42]	train-normal,1.26:369.638	test-normal,1.26:139.358
# [43]	train-normal,1.26:368.528	test-normal,1.26:139.659
# [44]	train-normal,1.26:367.663	test-normal,1.26:139.957
# [45]	train-normal,1.26:366.89	test-normal,1.26:140.21
# [46]	train-normal,1.26:366.121	test-normal,1.26:140.388
# [47]	train-normal,1.26:364.975	test-normal,1.26:140.569
# [48]	train-normal,1.26:364.311	test-normal,1.26:140.756
# [49]	train-normal,1.26:363.61	test-normal,1.26:140.843
# [50]	train-normal,1.26:363.008	test-normal,1.26:141.001
# [51]	train-normal,1.26:362.436	test-normal,1.26:141.124
# [52]	train-normal,1.26:362.036	test-normal,1.26:141.237
# [53]	train-normal,1.26:361.768	test-normal,1.26:141.413
# [54]	train-normal,1.26:361.546	test-normal,1.26:141.575
# [55]	train-normal,1.26:361.056	test-normal,1.26:141.47
# [56]	train-normal,1.26:360.707	test-normal,1.26:141.554
# [57]	train-normal,1.26:360.272	test-normal,1.26:141.613
# [58]	train-normal,1.26:359.888	test-normal,1.26:141.523
# [59]	train-normal,1.26:359.42	test-normal,1.26:141.496
# [60]	train-normal,1.26:359.12	test-normal,1.26:141.56
# [61]	train-normal,1.26:358.873	test-normal,1.26:141.567
# [62]	train-normal,1.26:358.347	test-normal,1.26:141.558
# [63]	train-normal,1.26:358.095	test-normal,1.26:141.685
# [64]	train-normal,1.26:357.525	test-normal,1.26:141.802
# [65]	train-normal,1.26:357.144	test-normal,1.26:141.728
# [66]	train-normal,1.26:356.93	test-normal,1.26:141.777
# [67]	train-normal,1.26:356.618	test-normal,1.26:141.707
# [68]	train-normal,1.26:356.232	test-normal,1.26:141.586
# [69]	train-normal,1.26:355.905	test-normal,1.26:141.65
# [70]	train-normal,1.26:355.705	test-normal,1.26:141.615
# [71]	train-normal,1.26:355.651	test-normal,1.26:141.678
# [72]	train-normal,1.26:354.984	test-normal,1.26:141.226
# [73]	train-normal,1.26:354.834	test-normal,1.26:141.27
# [74]	train-normal,1.26:354.573	test-normal,1.26:141.176
# [75]	train-normal,1.26:354.353	test-normal,1.26:141.169
# [76]	train-normal,1.26:354.076	test-normal,1.26:141.153
# [77]	train-normal,1.26:353.817	test-normal,1.26:141.167
# [78]	train-normal,1.26:353.376	test-normal,1.26:140.959
# [79]	train-normal,1.26:353.229	test-normal,1.26:140.922
# [80]	train-normal,1.26:353.078	test-normal,1.26:140.961
# [81]	train-normal,1.26:352.62	test-normal,1.26:141.168
# [82]	train-normal,1.26:352.561	test-normal,1.26:141.18
# [83]	train-normal,1.26:352.186	test-normal,1.26:140.73
# [84]	train-normal,1.26:352.094	test-normal,1.26:140.768
# [85]	train-normal,1.26:351.772	test-normal,1.26:140.869
# [86]	train-normal,1.26:351.643	test-normal,1.26:140.809
# [87]	train-normal,1.26:351.354	test-normal,1.26:140.815
# [88]	train-normal,1.26:351.159	test-normal,1.26:140.828
# [89]	train-normal,1.26:351.069	test-normal,1.26:140.916
# [90]	train-normal,1.26:350.762	test-normal,1.26:140.921
# [91]	train-normal,1.26:350.579	test-normal,1.26:140.941
# [92]	train-normal,1.26:350.322	test-normal,1.26:140.959
# [93]	train-normal,1.26:350.086	test-normal,1.26:140.858
# [94]	train-normal,1.26:350.077	test-normal,1.26:140.859
# [95]	train-normal,1.26:349.854	test-normal,1.26:140.923
# [96]	train-normal,1.26:349.719	test-normal,1.26:140.939
# [97]	train-normal,1.26:349.602	test-normal,1.26:140.909
# [98]	train-normal,1.26:349.359	test-normal,1.26:140.923
# [99]	train-normal,1.26:349.228	test-normal,1.26:140.886

# %%
data      = pd.read_csv('simulate_survival.csv')
rows,cols = data.shape[0],data.shape[1]
list1     = list(np.arange(rows))
sample    = random.sample(list1, 800)

# %%
train = data[data.index.isin(sample)]
test  = data[~data.index.isin(sample)]

# %%
X            = train[['x1','x2','x3']]
X_val        = test[['x1','x2','x3']]
y_lower      = train['left']
y_lower_val  = test['left']
y_higher     = train['right']
y_higher_val = test['right']

# %%
dataName    = 'simulate'
data_name   = dataName
title       = 'Loss=LogLoss,Data='+data_name+' Test Fold='+str(test_fold)
file_name   = title+'.png'
    
params = {'learning_rate':0.1, 'aft_noise_distribution' : 'normal', 'aft_sigma': 1.0,'eval_metric':'aft-nloglik@normal,1.0','objective':"aft:survival"}
bst    = generate_result(X,y_lower,y_higher,params,X_val,y_lower_val,y_higher_val)
chart_creation_xgboost(bst,title,file_name)
# Out:
# [0]	train-normal,1.0:nan	test-normal,1.0:nan
# [1]	train-normal,1.0:nan	test-normal,1.0:nan
# [2]	train-normal,1.0:nan	test-normal,1.0:nan
# [3]	train-normal,1.0:nan	test-normal,1.0:nan
# [4]	train-normal,1.0:nan	test-normal,1.0:nan
# [5]	train-normal,1.0:nan	test-normal,1.0:nan
# [6]	train-normal,1.0:nan	test-normal,1.0:nan
# [7]	train-normal,1.0:nan	test-normal,1.0:nan
# [8]	train-normal,1.0:nan	test-normal,1.0:nan
# [9]	train-normal,1.0:nan	test-normal,1.0:nan
# [10]	train-normal,1.0:nan	test-normal,1.0:nan
# [11]	train-normal,1.0:nan	test-normal,1.0:nan
# [12]	train-normal,1.0:nan	test-normal,1.0:nan
# [13]	train-normal,1.0:nan	test-normal,1.0:nan
# [14]	train-normal,1.0:nan	test-normal,1.0:nan
# [15]	train-normal,1.0:nan	test-normal,1.0:nan
# [16]	train-normal,1.0:nan	test-normal,1.0:nan
# [17]	train-normal,1.0:nan	test-normal,1.0:nan
# [18]	train-normal,1.0:nan	test-normal,1.0:nan
# [19]	train-normal,1.0:nan	test-normal,1.0:nan
# [20]	train-normal,1.0:nan	test-normal,1.0:nan
# [21]	train-normal,1.0:nan	test-normal,1.0:nan
# [22]	train-normal,1.0:nan	test-normal,1.0:nan
# [23]	train-normal,1.0:nan	test-normal,1.0:nan
# [24]	train-normal,1.0:nan	test-normal,1.0:nan
# [25]	train-normal,1.0:nan	test-normal,1.0:nan
# [26]	train-normal,1.0:nan	test-normal,1.0:nan
# [27]	train-normal,1.0:nan	test-normal,1.0:nan
# [28]	train-normal,1.0:nan	test-normal,1.0:nan
# [29]	train-normal,1.0:nan	test-normal,1.0:nan
# [30]	train-normal,1.0:nan	test-normal,1.0:nan
# [31]	train-normal,1.0:nan	test-normal,1.0:nan
# [32]	train-normal,1.0:nan	test-normal,1.0:nan
# [33]	train-normal,1.0:nan	test-normal,1.0:nan
# [34]	train-normal,1.0:nan	test-normal,1.0:nan
# [35]	train-normal,1.0:nan	test-normal,1.0:nan
# [36]	train-normal,1.0:nan	test-normal,1.0:nan
# [37]	train-normal,1.0:nan	test-normal,1.0:nan
# [38]	train-normal,1.0:nan	test-normal,1.0:nan
# [39]	train-normal,1.0:nan	test-normal,1.0:nan
# [40]	train-normal,1.0:nan	test-normal,1.0:nan
# [41]	train-normal,1.0:nan	test-normal,1.0:nan
# [42]	train-normal,1.0:nan	test-normal,1.0:nan
# [43]	train-normal,1.0:nan	test-normal,1.0:nan
# [44]	train-normal,1.0:nan	test-normal,1.0:nan
# [45]	train-normal,1.0:nan	test-normal,1.0:nan
# [46]	train-normal,1.0:nan	test-normal,1.0:nan
# [47]	train-normal,1.0:nan	test-normal,1.0:nan
# [48]	train-normal,1.0:nan	test-normal,1.0:nan
# [49]	train-normal,1.0:nan	test-normal,1.0:nan
# [50]	train-normal,1.0:nan	test-normal,1.0:nan
# [51]	train-normal,1.0:nan	test-normal,1.0:nan
# [52]	train-normal,1.0:nan	test-normal,1.0:nan
# [53]	train-normal,1.0:nan	test-normal,1.0:nan
# [54]	train-normal,1.0:nan	test-normal,1.0:nan
# [55]	train-normal,1.0:nan	test-normal,1.0:nan
# [56]	train-normal,1.0:nan	test-normal,1.0:nan
# [57]	train-normal,1.0:nan	test-normal,1.0:nan
# [58]	train-normal,1.0:nan	test-normal,1.0:nan
# [59]	train-normal,1.0:nan	test-normal,1.0:nan
# [60]	train-normal,1.0:nan	test-normal,1.0:nan
# [61]	train-normal,1.0:nan	test-normal,1.0:nan
# [62]	train-normal,1.0:nan	test-normal,1.0:nan
# [63]	train-normal,1.0:nan	test-normal,1.0:nan
# [64]	train-normal,1.0:nan	test-normal,1.0:nan
# [65]	train-normal,1.0:nan	test-normal,1.0:nan
# [66]	train-normal,1.0:nan	test-normal,1.0:nan
# [67]	train-normal,1.0:nan	test-normal,1.0:nan
# [68]	train-normal,1.0:nan	test-normal,1.0:nan
# [69]	train-normal,1.0:nan	test-normal,1.0:nan
# [70]	train-normal,1.0:nan	test-normal,1.0:nan
# [71]	train-normal,1.0:nan	test-normal,1.0:nan
# [72]	train-normal,1.0:nan	test-normal,1.0:nan
# [73]	train-normal,1.0:nan	test-normal,1.0:nan
# [74]	train-normal,1.0:nan	test-normal,1.0:nan
# [75]	train-normal,1.0:nan	test-normal,1.0:nan
# [76]	train-normal,1.0:nan	test-normal,1.0:nan
# [77]	train-normal,1.0:nan	test-normal,1.0:nan
# [78]	train-normal,1.0:nan	test-normal,1.0:nan
# [79]	train-normal,1.0:nan	test-normal,1.0:nan
# [80]	train-normal,1.0:nan	test-normal,1.0:nan
# [81]	train-normal,1.0:nan	test-normal,1.0:nan
# [82]	train-normal,1.0:nan	test-normal,1.0:nan
# [83]	train-normal,1.0:nan	test-normal,1.0:nan
# [84]	train-normal,1.0:nan	test-normal,1.0:nan
# [85]	train-normal,1.0:nan	test-normal,1.0:nan
# [86]	train-normal,1.0:nan	test-normal,1.0:nan
# [87]	train-normal,1.0:nan	test-normal,1.0:nan
# [88]	train-normal,1.0:nan	test-normal,1.0:nan
# [89]	train-normal,1.0:nan	test-normal,1.0:nan
# [90]	train-normal,1.0:nan	test-normal,1.0:nan
# [91]	train-normal,1.0:nan	test-normal,1.0:nan
# [92]	train-normal,1.0:nan	test-normal,1.0:nan
# [93]	train-normal,1.0:nan	test-normal,1.0:nan
# [94]	train-normal,1.0:nan	test-normal,1.0:nan
# [95]	train-normal,1.0:nan	test-normal,1.0:nan
# [96]	train-normal,1.0:nan	test-normal,1.0:nan
# [97]	train-normal,1.0:nan	test-normal,1.0:nan
# [98]	train-normal,1.0:nan	test-normal,1.0:nan
# [99]	train-normal,1.0:nan	test-normal,1.0:nan
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-e1686ec7be0e> in <module>
#       6 params = {'learning_rate':0.1, 'aft_noise_distribution' : 'normal', 'aft_sigma': 1.0,'eval_metric':'aft-nloglik@normal,1.0','objective':"aft:survival"}
#       7 bst    = generate_result(X,y_lower,y_higher,params,X_val,y_lower_val,y_higher_val)
# ----> 8 chart_creation_xgboost(bst,title,file_name)
#
# TypeError: chart_creation_xgboost() missing 1 required positional argument: 'distribution'
